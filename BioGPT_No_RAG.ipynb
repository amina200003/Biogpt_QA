# %% [markdown]
# <a href="https://colab.research.google.com/github/amina200003/Biogpt_QA/blob/main/BioGPT_No_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install torch transformers datasets sentence-transformers
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.55.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (4.0.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (5.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.16.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 41.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127

# %%
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace BioGPT_No_RAG.ipynb
# Out:
# [NbConvertApp] WARNING | pattern 'BioGPT_No_RAG.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# =======
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# -y
#     Answer yes to any questions instead of prompting.
#     Equivalent to: [--JupyterApp.answer_yes=True]
# --execute
#     Execute the notebook prior to export.
#     Equivalent to: [--ExecutePreprocessor.enabled=True]
# --allow-errors
#     Continue notebook execution even if one of the cells throws an error and include the error message in the cell output (the default behaviour is to abort conversion). This flag is only relevant if '--execute' was specified, too.
#     Equivalent to: [--ExecutePreprocessor.allow_errors=True]
# --stdin
#     read a single notebook file from stdin. Write the resulting notebook with default basename 'notebook.*'
#     Equivalent to: [--NbConvertApp.from_stdin=True]
# --stdout
#     Write notebook output to stdout instead of files.
#     Equivalent to: [--NbConvertApp.writer_class=StdoutWriter]
# --inplace
#     Run nbconvert in place, overwriting the existing notebook (only
#             relevant when converting to notebook format)
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory=]
# --clear-output
#     Clear output of current file and save in place,
#             overwriting the existing notebook.
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory= --ClearOutputPreprocessor.enabled=True]
# --coalesce-streams
#     Coalesce consecutive stdout and stderr outputs into one stream (within each cell).
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory= --CoalesceStreamsPreprocessor.enabled=True]
# --no-prompt
#     Exclude input and output prompts from converted document.
#     Equivalent to: [--TemplateExporter.exclude_input_prompt=True --TemplateExporter.exclude_output_prompt=True]
# --no-input
#     Exclude input cells and output prompts from converted document.
#             This mode is ideal for generating code-free reports.
#     Equivalent to: [--TemplateExporter.exclude_output_prompt=True --TemplateExporter.exclude_input=True --TemplateExporter.exclude_input_prompt=True]
# --allow-chromium-download
#     Whether to allow downloading chromium if no suitable version is found on the system.
#     Equivalent to: [--WebPDFExporter.allow_chromium_download=True]
# --disable-chromium-sandbox
#     Disable chromium security sandbox when converting to PDF..
#     Equivalent to: [--WebPDFExporter.disable_sandbox=True]
# --show-input
#     Shows code input. This flag is only useful for dejavu users.
#     Equivalent to: [--TemplateExporter.exclude_input=False]
# --embed-images
#     Embed the images as base64 dataurls in the output. This flag is only useful for the HTML/WebPDF/Slides exports.
#     Equivalent to: [--HTMLExporter.embed_images=True]
# --sanitize-html
#     Whether the HTML in Markdown cells and cell outputs should be sanitized..
#     Equivalent to: [--HTMLExporter.sanitize_html=True]
# --log-level=<Enum>
#     Set the log level by value or name.
#     Choices: any of [0, 10, 20, 30, 40, 50, 'DEBUG', 'INFO', 'WARN', 'ERROR', 'CRITICAL']
#     Default: 30
#     Equivalent to: [--Application.log_level]
# --config=<Unicode>
#     Full path of a config file.
#     Default: ''
#     Equivalent to: [--JupyterApp.config_file]
# --to=<Unicode>
#     The export format to be used, either one of the built-in formats
#             ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'qtpdf', 'qtpng', 'rst', 'script', 'slides', 'webpdf']
#             or a dotted object name that represents the import path for an
#             ``Exporter`` class
#     Default: ''
#     Equivalent to: [--NbConvertApp.export_format]
# --template=<Unicode>
#     Name of the template to use
#     Default: ''
#     Equivalent to: [--TemplateExporter.template_name]
# --template-file=<Unicode>
#     Name of the template file to use
#     Default: None
#     Equivalent to: [--TemplateExporter.template_file]
# --theme=<Unicode>
#     Template specific theme(e.g. the name of a JupyterLab CSS theme distributed
#     as prebuilt extension for the lab template)
#     Default: 'light'
#     Equivalent to: [--HTMLExporter.theme]
# --sanitize_html=<Bool>
#     Whether the HTML in Markdown cells and cell outputs should be sanitized.This
#     should be set to True by nbviewer or similar tools.
#     Default: False
#     Equivalent to: [--HTMLExporter.sanitize_html]
# --writer=<DottedObjectName>
#     Writer class used to write the
#                                         results of the conversion
#     Default: 'FilesWriter'
#     Equivalent to: [--NbConvertApp.writer_class]
# --post=<DottedOrNone>
#     PostProcessor class used to write the
#                                         results of the conversion
#     Default: ''
#     Equivalent to: [--NbConvertApp.postprocessor_class]
# --output=<Unicode>
#     Overwrite base name use for output files.
#                 Supports pattern replacements '{notebook_name}'.
#     Default: '{notebook_name}'
#     Equivalent to: [--NbConvertApp.output_base]
# --output-dir=<Unicode>
#     Directory to write output(s) to. Defaults
#                                   to output to the directory of each notebook. To recover
#                                   previous default behaviour (outputting to the current
#                                   working directory) use . as the flag value.
#     Default: ''
#     Equivalent to: [--FilesWriter.build_directory]
# --reveal-prefix=<Unicode>
#     The URL prefix for reveal.js (version 3.x).
#             This defaults to the reveal CDN, but can be any url pointing to a copy
#             of reveal.js.
#             For speaker notes to work, this must be a relative path to a local
#             copy of reveal.js: e.g., "reveal.js".
#             If a relative path is given, it must be a subdirectory of the
#             current directory (from which the server is run).
#             See the usage documentation
#             (https://nbconvert.readthedocs.io/en/latest/usage.html#reveal-js-html-slideshow)
#             for more details.
#     Default: ''
#     Equivalent to: [--SlidesExporter.reveal_url_prefix]
# --nbformat=<Enum>
#     The nbformat version to write.
#             Use this to downgrade notebooks.
#     Choices: any of [1, 2, 3, 4]
#     Default: 4
#     Equivalent to: [--NotebookExporter.nbformat_version]
#
# Examples
# --------
#
#     The simplest way to use nbconvert is
#
#             > jupyter nbconvert mynotebook.ipynb --to html
#
#             Options include ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'qtpdf', 'qtpng', 'rst', 'script', 'slides', 'webpdf'].
#
#             > jupyter nbconvert --to latex mynotebook.ipynb
#
#             Both HTML and LaTeX support multiple output templates. LaTeX includes
#             'base', 'article' and 'report'.  HTML includes 'basic', 'lab' and
#             'classic'. You can specify the flavor of the format used.
#
#             > jupyter nbconvert --to html --template lab mynotebook.ipynb
#
#             You can also pipe the output to stdout, rather than a file
#
#             > jupyter nbconvert mynotebook.ipynb --stdout
#
#             PDF is generated via latex
#
#             > jupyter nbconvert mynotebook.ipynb --to pdf
#
#             You can get (and serve) a Reveal.js-powered slideshow
#
#             > jupyter nbconvert myslides.ipynb --to slides --post serve
#
#             Multiple notebooks can be given at the command line in a couple of
#             different ways:
#
#             > jupyter nbconvert notebook*.ipynb
#             > jupyter nbconvert notebook1.ipynb notebook2.ipynb
#
#             or you can specify the notebooks list in a config file, containing::
#
#                 c.NbConvertApp.notebooks = ["my_notebook.ipynb"]
#
#             > jupyter nbconvert --config mycfg.py
#
# To see all available configurables, use `--help-all`.

# %%
! pip install sacremoses
# Out:
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacremoses) (2024.11.6)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from sacremoses) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from sacremoses) (1.5.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sacremoses) (4.67.1)
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 15.7 MB/s eta 0:00:00
# Installing collected packages: sacremoses
# Successfully installed sacremoses-0.1.1

# %%
from transformers import AutoTokenizer, BioGptForCausalLM

model= "microsoft/biogpt-large"
tokenizer = AutoTokenizer.from_pretrained(model)
biogpt = BioGptForCausalLM.from_pretrained(model)

def ask_biogpt(questions):
  answers=[]
  for q in questions:
    prompt= f"Question: {q}\nAnswer:"
    inputs= tokenizer(prompt, return_tensors="pt")
    output= biogpt.generate(**inputs, max_new_tokens=200)
    answer= tokenizer.decode(output[0], skip_special_tokens=True)
    answers.append(answer)
  return answers

query =  [
    "What are the symptoms of  breast cancer ?",
    "What should I do when I have a headache ?",
     "How does hypertension affect the heart?",
    "How can I see that I have skin cancer ?",
    "Is it safe to take paracetamol and ibuprofen together?",
    "What should I do if I experience chest pain ?",
    "What are the common symptoms of endometriosis?",
    "What are the signs of a seizure ?",
    "What are the best ways to manage chronic pain?",
    " I have a lump in my leg, What should I do?",
    "How to I know if I have food allergy?",
    "How long does it take to recover from a fractured tibia?",
    "What are the signs of a stroke?",
    "What are the early signs of pregnancy?",
    " Is an acute headache a symptom of brain cancer?",

    "Is ice effective for a sprained ankle ?",
    "How can I ease my period pain ?",
    "There is a black dot in my vision. Do I have eye cancer ?",
    " There is a yellow dot in my left eye. What it is ?",
    "I have a lump in my neck, should I be worried?",
    "At what age should a baby drink water?",
    "Why my heart and my left arm hurts ?",
    "Why does hurt when I pee?",
    "What causes intermittent headaches?",



    "What are the recommended guidelines for gestational diabetes screening and management?", #OK
    "How does hypertension contribute to the development of atrial fibrillation?",
    "How can we differentiate between essential tremor and Parkinson’s disease?",#OK
    "What are the indications for emergency C-section in labor?",#OK
    "How can we differentiate between bacterial and viral meningitis based on clinical and laboratory findings?",
    "How can we differentiate between an ischemic and a hemorrhagic stroke based on clinical presentation?",
    "What are the hemodynamic effects of propofol versus etomidate in induction of anesthesia?",

    "How often should I get a physical check-up?",
    "What vaccines do I need as an adult?",
    "Is it normal to feel tired all the time?",
    "What does it mean if my blood pressure is slightly high?",
    "How much water should I drink daily?",
    "What should I do if I have a persistent cough?",
    "When is a fever considered dangerous?",
    "What are the early signs of diabetes?",
    "How long should I take antibiotics for?",
    "Can I stop taking my medication if I feel better?",
    "Is it safe to take expired medication?",
    "When should I get a cholesterol test?",
    "Do I really need a flu shot every year?",
    "What can I do to strengthen my immune system?",
    "How can I lower my risk of heart disease?",
    "Is intermittent fasting safe ?",
    "How can I lose weight in a healthy way?",
    "What’s the best diet for managing high blood pressure?",
    "How much exercise should I get each week?",
    "Can too much screen time affect my sleep?",
    "How do I know if I have anxiety or just stress?",
    "What are the signs of depression?",
    "Can lack of sleep affect my mental health?",
    "Is it normal to feel unmotivated all the time?",
    "What birth control options are best for me?",
    "What are the signs of early menopause?",
    "Is it safe to take supplements during pregnancy?",
    "Should I be screened for prostate cancer?",
    "What can I do to improve testosterone levels naturally?",
    "Why do I feel tired even after 8 hours of sleep?",
    "Is hair loss preventable?",
    "How often should I get a colonoscopy?",
    "How can I manage my asthma better?",
    "What’s the best way to monitor my blood sugar?",
    "Can high cholesterol be managed without medication?",
    "How can I prevent my arthritis from getting worse?",
    "What is to long COVID?",
    "Should I get genetic testing for inherited diseases?",
    "How do I boost my energy levels naturally?",
    "Does stress affect physical health?",
    "Can gut health impact my mood?",
    "What are the warning signs of cancer I shouldn’t ignore?",
    "What should I do if I can't sleep at night?",
    "Is it normal to hear a ringing in my ears?",
    "How can I tell if a mole is dangerous?",
    "Are supplements like vitamin D necessary?",
    "Why do I feel dizzy when I stand up quickly?",
    "How long should a cold last?",
    "Is it okay to skip breakfast?",
    "Can allergies develop later in life?",
    "What is the difference between a cold and the flu?",
    "Should I be worried about numbness in my fingers?",
    "How do I know if I have high blood sugar?",
    "Can diet really affect my mental health?",
    "Why does my stomach hurt after eating?",
    "Can I exercise if I have joint pain?",
    "Is it safe to drink alcohol while taking antibiotics?",
    "What is the healthiest way to quit smoking?",
    "Why do I bruise easily?",
    "Can poor posture cause back pain?",
    "Is my shortness of breath normal during exercise?",
    "What are common side effects of birth control?",
    "Why do I feel anxious for no reason?",
    "Can I catch the same virus twice?",
    "How can I protect my vision as I age?",
    "Are probiotics actually beneficial?",
    "What is the difference between IBS and IBD?",
    "Can too much caffeine affect my heart?",
    "Should I be worried about my cholesterol if I’m slim?",
    "Why do I get leg cramps at night?",
    "What are the signs of an iron deficiency?",
    "Can I drink coffee if I have high blood pressure?",
    "Is it okay to take melatonin regularly?",
    "How can I reduce my risk of dementia?",
    "Why is my skin suddenly so dry?",
    "Can I still get pregnant after 40?",
    "What are normal blood sugar levels?",
    "Can dehydration cause headaches?",
    "How can I tell if I have a food intolerance?",
    "What vaccines do I need before traveling?",
    "How do I know if I need therapy?",
    "How do I manage seasonal allergies?",
    "Why do my hands tingle sometimes?",
    "Can a lack of exercise cause health problems?",
    "Should I be using sunscreen every day?",
    "Is it normal to forget things more often with age?",
    "Can long-term screen time affect my eyesight?",


"Why do I feel dizzy after standing up for a few seconds?",

"How do I know if I am dehydrated?",

"What should I do if my nosebleeds often?",

"Can stress cause stomach pain?",

"Why do I sometimes feel my heart racing suddenly?",

"How do I know if my cough is due to allergies or a cold?",

"What should I do if I accidentally take the wrong medication dose?",

"Is it normal to feel short of breath when climbing stairs?",

"Why do I sometimes wake up with a headache?",

"How can I tell if I have low blood pressure?",

"Can lack of sleep cause weight gain?",

"Why do my legs feel heavy at night?",

"What should I do if my vision suddenly becomes blurry?",

"How do I know if my back pain is serious?",

"Why do my hands and feet get cold easily?",

"Can anxiety cause chest tightness?",

"How long should a bruise take to heal?",

"What causes hiccups and how can I stop them?",

"Should I be concerned about occasional heart palpitations?",

"How do I know if I have vitamin deficiency?",

"Can digestive problems be related to stress?",

"Why do I feel sleepy after eating?",

"Is it normal to sweat a lot at night?",

"Can certain foods trigger migraines?",

"What does it mean if I hear a popping sound in my joints?",

"How do I know if I am having an allergic reaction to medication?",

"Why do I get dizzy after intense exercise?",

"Can dehydration affect my heart rate?",

"What should I do if I feel sudden sharp pain in my abdomen?",

"Can low iron cause dizziness?",

"Is it normal to lose appetite when stressed?",

"How do I know if I have sleep apnea?",

"Can earwax buildup cause dizziness?",

"Why does my stomach bloat after eating certain foods?",

"What can I do to prevent leg swelling during long flights?",

"Can certain medications make me feel more tired?",

"Why do I sometimes feel tingling in my lips?",

"How do I know if I am having an asthma attack?",

"Can a lack of physical activity cause constipation?",

"Why do I sometimes feel my ear “pop” without being on a plane?",

"What should I do if I feel sudden weakness in my legs?",

"Can drinking too little water cause constipation?",

"How do I know if I am overexercising?",

"Is it normal to have mild chest discomfort after running?",

"Why does my heart beat faster when I am anxious?",

"Can changes in weather trigger joint pain?",

"Why do I feel shaky when I haven’t eaten for a while?",

"What should I do if I notice blood in my stool?",

"Can stress cause irregular periods?",

"Why do I get motion sickness in cars or boats?",

"How do I know if I am lactose intolerant?",

"Can skipping meals affect my blood pressure?",

"What should I do if I accidentally swallow a small object?",

"Why does my throat feel tight sometimes?",

"Can lack of vitamin D cause fatigue?",

"Why do I get headaches when I don’t drink coffee?",

"How do I know if I am allergic to pollen?",

"Can using headphones for long periods affect my ears?",

"Why do I feel lightheaded after a hot shower?",

"What should I do if I faint suddenly?",

"Can stress cause hair loss?",

"Why do I sometimes feel like my heart skips a beat?",

"Can dehydration affect my mood?",

"How do I know if my fatigue is due to anemia?",

"Why do I feel bloated during my menstrual cycle?",

"Can too much exercise affect my immune system?",

"Why does my skin itch without a rash?",

"Can certain foods make heartburn worse?",

"Why do I sometimes feel pressure in my ears?",

"How do I know if my frequent urination is normal?",

"Can changes in sleep schedule affect my digestion?",

"Why do I feel sudden chills without fever?",

"How do I know if my wound is infected?",

"Can anxiety cause tingling in the body?",

"Why do I sometimes lose balance when turning quickly?",

"Can dehydration cause muscle cramps?",

"How do I know if my blood sugar is too low without a test?",

"Why do I wake up feeling like my heart is racing?",

"Can eating too fast cause stomach pain?",

"How do I know if my headache is from eye strain?",

"Can cold weather trigger breathing difficulties?",

]

A= ask_biogpt(query)

for q,r in zip(query,A):
  print(f"question:{q} \n Answer:{r} \n")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/256 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/658 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/6.29G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# question:What are the symptoms of  breast cancer ?
#  Answer:Question: What are the symptoms of breast cancer? Answer: The symptoms of breast cancer are pain, swelling, redness, and a lump. < / FREETEXT > < / ABSTRACT > ▃
#
# question:What should I do when I have a headache ?
#  Answer:Question: What should I do when I have a headache? Answer: I'm taking a beta blocker. < / FREETEXT > < / TITLE > ▃
#
# question:How does hypertension affect the heart?
#  Answer:Question: How does hypertension affect the heart? Answer: Hypertension causes cardiac hypertrophy and fibrosis. < / FREETEXT > < / TITLE > ▃
#
# question:How can I see that I have skin cancer ?
#  Answer:Question: How can I see that I have skin cancer? Answer: The lesion is a basal cell carcinoma. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Is it safe to take paracetamol and ibuprofen together?
#  Answer:Question: Is it safe to take paracetamol and ibuprofen together? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:What should I do if I experience chest pain ?
#  Answer:Question: What should I do if I experience chest pain? Answer: Don't worry about the heart. < / FREETEXT > < / TITLE > ▃
#
# question:What are the common symptoms of endometriosis?
#  Answer:Question: What are the common symptoms of endometriosis? Answer: Dysmenorrhea, dyspareunia, and chronic pelvic pain are the most common symptoms of endometriosis. < / FREETEXT > < / ABSTRACT > ▃
#
# question:What are the signs of a seizure ?
#  Answer:Question: What are the signs of a seizure? Answer: Seizures are characterized by a sudden onset of altered mental status, motor activity, and autonomic changes. < / FREETEXT > < / ABSTRACT > ▃
#
# question:What are the best ways to manage chronic pain?
#  Answer:Question: What are the best ways to manage chronic pain? Answer: The use of opioids is associated with a number of adverse effects, including addiction, constipation, and respiratory depression. < / FREETEXT > < / ABSTRACT > ▃
#
# question: I have a lump in my leg, What should I do?
#  Answer:Question: I have a lump in my leg, What should I do? Answer: A lump in my leg should be removed. < / FREETEXT > < / TITLE > ▃
#
# question:How to I know if I have food allergy?
#  Answer:Question: How to I know if I have food allergy? Answer: If I have food allergy, then I should avoid the food. < / FREETEXT > < / ABSTRACT > ▃
#
# question:How long does it take to recover from a fractured tibia?
#  Answer:Question: How long does it take to recover from a fractured tibia? Answer: It takes at least 1 2 weeks. < / FREETEXT > < / TITLE > ▃
#
# question:What are the signs of a stroke?
#  Answer:Question: What are the signs of a stroke? Answer: The patient's history and physical examination are the most important diagnostic tools. < / FREETEXT > < / ABSTRACT > ▃
#
# question:What are the early signs of pregnancy?
#  Answer:Question: What are the early signs of pregnancy? Answer: The presence of a gestational sac is the earliest sign of pregnancy. < / FREETEXT > < / ABSTRACT > ▃
#
# question: Is an acute headache a symptom of brain cancer?
#  Answer:Question: Is an acute headache a symptom of brain cancer? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:Is ice effective for a sprained ankle ?
#  Answer:Question: Is ice effective for a sprained ankle? Answer: Ice is effective for a sprained ankle. < / FREETEXT > < / TITLE > ▃
#
# question:How can I ease my period pain ?
#  Answer:Question: How can I ease my period pain? Answer: The use of a cervical collar can help to reduce the pain of a period of rest. < / FREETEXT > < / TITLE > ▃
#
# question:There is a black dot in my vision. Do I have eye cancer ?
#  Answer:Question: There is a black dot in my vision. Do I have eye cancer? Answer: I have a black dot in my eye. < / FREETEXT > < / TITLE > ▃
#
# question: There is a yellow dot in my left eye. What it is ?
#  Answer:Question: There is a yellow dot in my left eye. What it is? Answer: A choroidal nevus. < / FREETEXT > < / TITLE > ▃
#
# question:I have a lump in my neck, should I be worried?
#  Answer:Question: I have a lump in my neck, should I be worried? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:At what age should a baby drink water?
#  Answer:Question: At what age should a baby drink water? Answer: Age < 2 years. < / FREETEXT > < / TITLE > ▃
#
# question:Why my heart and my left arm hurts ?
#  Answer:Question: Why my heart and my left arm hurts? Answer: the cause is a large thrombus in the left atrium. < / FREETEXT > < / TITLE > ▃
#
# question:Why does hurt when I pee?
#  Answer:Question: Why does hurt when I pee? Answer: I'm a patient with a chronic pain syndrome. < / FREETEXT > < / TITLE > ▃
#
# question:What causes intermittent headaches?
#  Answer:Question: What causes intermittent headaches? Answer: The headache is caused by a dural arteriovenous fistula. < / FREETEXT > < / TITLE > ▃
#
# question:What are the recommended guidelines for gestational diabetes screening and management?
#  Answer:Question: What are the recommended guidelines for gestational diabetes screening and management? Answer: The American College of Obstetricians and Gynecologists recommends universal screening for gestational diabetes mellitus (GDM) in all pregnant women. The American Diabetes Association recommends screening for GDM in women with risk factors, such as a history of GDM, obesity, or a family history of diabetes. The American College of Obstetricians and Gynecologists recommends that GDM be diagnosed using a 7 5-g oral glucose tolerance test (OGTT). The American College of Obstetricians and Gynecologists recommends that GDM be treated with diet and exercise, with the addition of insulin if necessary. < / FREETEXT > < / ABSTRACT > ▃
#
# question:How does hypertension contribute to the development of atrial fibrillation?
#  Answer:Question: How does hypertension contribute to the development of atrial fibrillation? Answer: Hypertension is a risk factor for the development of atrial fibrillation. < / FREETEXT > < / TITLE > ▃
#
# question:How can we differentiate between essential tremor and Parkinson’s disease?
#  Answer:Question: How can we differentiate between essential tremor and Parkinson ’ s disease? Answer: Essential tremor is a monosymptomatic disorder, whereas Parkinson ’ s disease is a multisymptomatic disorder. < / FREETEXT > < / PARAGRAPH > ▃ < PARAGRAPH > < FREETEXT > Essential tremor (ET) is the most common movement disorder, with a prevalence of 4% – 1 8% in the general population. 1, 2 It is characterized by postural and kinetic tremor of the upper limbs, head, voice, and trunk. 3, 4 The tremor is usually bilateral and symmetric, and it is often accompanied by head tremor. 5, 6 The tremor is usually mild and does not interfere with daily activities. 7 However, in some patients, the tremor is severe and disabling, and it can be associated with head tremor, voice tremor, and dystonic posturing of the hands. 8, 9 < / FREETEXT > < / PARAGRAPH > ▃ < PARAGRAPH > < FREETEXT > The diagnosis of ET is based on the presence of a postural and kinetic tremor of the upper limbs. 1 0 The tremor is usually mild
#
# question:What are the indications for emergency C-section in labor?
#  Answer:Question: What are the indications for emergency C-section in labor? Answer: C-section is indicated in cases of fetal distress, maternal or fetal infection, and in cases of breech presentation. < / FREETEXT > < / ABSTRACT > ▃
#
# question:How can we differentiate between bacterial and viral meningitis based on clinical and laboratory findings?
#  Answer:Question: How can we differentiate between bacterial and viral meningitis based on clinical and laboratory findings? Answer: The combination of the following clinical and laboratory findings is highly suggestive of bacterial meningitis: age < 2 years, fever, neck stiffness, altered mental status, and cerebrospinal fluid (CSF) glucose < 4 0 mg / dL. < / FREETEXT > < / ABSTRACT > ▃
#
# question:How can we differentiate between an ischemic and a hemorrhagic stroke based on clinical presentation?
#  Answer:Question: How can we differentiate between an ischemic and a hemorrhagic stroke based on clinical presentation? Answer: The presence of a headache, nausea, vomiting, and a history of hypertension are all associated with an ischemic stroke. < / FREETEXT > < / ABSTRACT > ▃
#
# question:What are the hemodynamic effects of propofol versus etomidate in induction of anesthesia?
#  Answer:Question: What are the hemodynamic effects of propofol versus etomidate in induction of anesthesia? Answer: Propofol has a more pronounced effect on the systemic vascular resistance than etomidate. < / FREETEXT > < / TITLE > ▃
#
# question:How often should I get a physical check-up?
#  Answer:Question: How often should I get a physical check-up? Answer: I don't need to have a physical check-up every year. < / FREETEXT > < / TITLE > ▃
#
# question:What vaccines do I need as an adult?
#  Answer:Question: What vaccines do I need as an adult? Answer: The influenza vaccine. < / FREETEXT > < / TITLE > ▃
#
# question:Is it normal to feel tired all the time?
#  Answer:Question: Is it normal to feel tired all the time? Answer: It is normal to feel tired all the time. < / FREETEXT > < / TITLE > ▃
#
# question:What does it mean if my blood pressure is slightly high?
#  Answer:Question: What does it mean if my blood pressure is slightly high? Answer: It's normal blood pressure. < / FREETEXT > < / TITLE > ▃
#
# question:How much water should I drink daily?
#  Answer:Question: How much water should I drink daily? Answer: A daily water intake of 1. 5 L is recommended. < / FREETEXT > < / TITLE > ▃
#
# question:What should I do if I have a persistent cough?
#  Answer:Question: What should I do if I have a persistent cough? Answer: Do you have a cough that is not responsive to usual therapy? < / FREETEXT > < / TITLE > ▃
#
# question:When is a fever considered dangerous?
#  Answer:Question: When is a fever considered dangerous? Answer: "Not". < / FREETEXT > < / TITLE > ▃
#
# question:What are the early signs of diabetes?
#  Answer:Question: What are the early signs of diabetes? Answer: The presence of microalbuminuria is an early sign of diabetes. < / FREETEXT > < / ABSTRACT > ▃
#
# question:How long should I take antibiotics for?
#  Answer:Question: How long should I take antibiotics for? Answer: For most patients, antibiotics should be taken for at least 5 days. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can I stop taking my medication if I feel better?
#  Answer:Question: Can I stop taking my medication if I feel better? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:Is it safe to take expired medication?
#  Answer:Question: Is it safe to take expired medication? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:When should I get a cholesterol test?
#  Answer:Question: When should I get a cholesterol test? Answer: When is a cholesterol test indicated? < / FREETEXT > < / TITLE > ▃
#
# question:Do I really need a flu shot every year?
#  Answer:Question: Do I really need a flu shot every year? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:What can I do to strengthen my immune system?
#  Answer:Question: What can I do to strengthen my immune system? Answer: The immune system can be strengthened by exercise. < / FREETEXT > < / TITLE > ▃
#
# question:How can I lower my risk of heart disease?
#  Answer:Question: How can I lower my risk of heart disease? Answer: A low-carbohydrate, high-protein diet is effective for reducing the risk of heart disease. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Is intermittent fasting safe ?
#  Answer:Question: Is intermittent fasting safe? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:How can I lose weight in a healthy way?
#  Answer:Question: How can I lose weight in a healthy way? Answer: exercise is the key to weight loss. < / FREETEXT > < / TITLE > ▃
#
# question:What’s the best diet for managing high blood pressure?
#  Answer:Question: What ’ s the best diet for managing high blood pressure? Answer: A low-sodium, low-potassium diet is the best diet for managing high blood pressure. < / FREETEXT > < / TITLE > ▃
#
# question:How much exercise should I get each week?
#  Answer:Question: How much exercise should I get each week? Answer: The answer is "no." < / FREETEXT > < / TITLE > ▃
#
# question:Can too much screen time affect my sleep?
#  Answer:Question: Can too much screen time affect my sleep? Answer: Excessive screen time is associated with poor sleep quality. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if I have anxiety or just stress?
#  Answer:Question: How do I know if I have anxiety or just stress? Answer: I am anxious. < / FREETEXT > < / TITLE > ▃
#
# question:What are the signs of depression?
#  Answer:Question: What are the signs of depression? Answer: The signs of depression are a combination of physical symptoms, cognitive symptoms, and emotional symptoms. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can lack of sleep affect my mental health?
#  Answer:Question: Can lack of sleep affect my mental health? Answer: Lack of sleep is associated with depression and anxiety. < / FREETEXT > < / TITLE > ▃
#
# question:Is it normal to feel unmotivated all the time?
#  Answer:Question: Is it normal to feel unmotivated all the time? Answer: It is normal to feel unmotivated all the time. < / FREETEXT > < / TITLE > ▃
#
# question:What birth control options are best for me?
#  Answer:Question: What birth control options are best for me? Answer: I use a levonorgestrel intrauterine system. < / FREETEXT > < / TITLE > ▃
#
# question:What are the signs of early menopause?
#  Answer:Question: What are the signs of early menopause? Answer: Early menopause is associated with increased risk of cardiovascular disease, osteoporosis, and depression. < / FREETEXT > < / TITLE > ▃
#
# question:Is it safe to take supplements during pregnancy?
#  Answer:Question: Is it safe to take supplements during pregnancy? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:Should I be screened for prostate cancer?
#  Answer:Question: Should I be screened for prostate cancer? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:What can I do to improve testosterone levels naturally?
#  Answer:Question: What can I do to improve testosterone levels naturally? Answer: Testosterone replacement therapy is effective in improving testosterone levels in hypogonadal men. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I feel tired even after 8 hours of sleep?
#  Answer:Question: Why do I feel tired even after 8 hours of sleep? Answer: The feeling of tiredness is caused by the lack of sleep. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Is hair loss preventable?
#  Answer:Question: Is hair loss preventable? Answer: There is no evidence that hair loss is preventable. < / FREETEXT > < / TITLE > ▃
#
# question:How often should I get a colonoscopy?
#  Answer:Question: How often should I get a colonoscopy? Answer: The risk of colorectal cancer is low in average-risk patients. < / FREETEXT > < / TITLE > ▃
#
# question:How can I manage my asthma better?
#  Answer:Question: How can I manage my asthma better? Answer: I can do better with a combination of inhaled corticosteroids and long-acting beta-agonists. < / FREETEXT > < / TITLE > ▃
#
# question:What’s the best way to monitor my blood sugar?
#  Answer:Question: What ’ s the best way to monitor my blood sugar? Answer: The glucose meter is the best way to monitor my blood sugar. < / FREETEXT > < / PARAGRAPH > ▃ < PARAGRAPH > < FREETEXT > The patient is a 5 5-year-old man with a history of type 2 diabetes mellitus and hypertension. He was diagnosed with type 2 diabetes mellitus in 2 0 0 9 and was treated with metformin, glimepiride, and sitagliptin. He had a glycated hemoglobin (HbA1c) level of 7. 5% and was taking metformin 5 0 0 mg twice daily and glimepiride 1 mg once daily. He had a body mass index of 3 0. 5 kg / m 2 and a waist circumference of 1 0 2 cm. He had no history of smoking or alcohol use. He had no family history of diabetes mellitus. < / FREETEXT > < / PARAGRAPH > ▃ < PARAGRAPH > < FREETEXT > On examination, his blood pressure was 1 2 0 / 7 0 mm Hg, heart rate was 7 2 beats per minute, and respiratory rate was 2
#
# question:Can high cholesterol be managed without medication?
#  Answer:Question: Can high cholesterol be managed without medication? Answer: High cholesterol can be managed without medication. < / FREETEXT > < / TITLE > ▃
#
# question:How can I prevent my arthritis from getting worse?
#  Answer:Question: How can I prevent my arthritis from getting worse? Answer: Exercise is the best treatment for arthritis. < / FREETEXT > < / TITLE > ▃
#
# question:What is to long COVID?
#  Answer:Question: What is to long COVID? Answer: The patient is a young woman with a history of asthma and chronic obstructive pulmonary disease (COPD). She has been hospitalized for pneumonia and has been prescribed antibiotics. She has been diagnosed with COVID-1 9 and has been prescribed oseltamivir. She has been admitted to the hospital for a second time for pneumonia. She has been prescribed antibiotics and oseltamivir. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Should I get genetic testing for inherited diseases?
#  Answer:Question: Should I get genetic testing for inherited diseases? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:How do I boost my energy levels naturally?
#  Answer:Question: How do I boost my energy levels naturally? Answer: A simple exercise program can help you. < / FREETEXT > < / TITLE > ▃
#
# question:Does stress affect physical health?
#  Answer:Question: Does stress affect physical health? Answer: Stress does not affect physical health. < / FREETEXT > < / TITLE > ▃
#
# question:Can gut health impact my mood?
#  Answer:Question: Can gut health impact my mood? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:What are the warning signs of cancer I shouldn’t ignore?
#  Answer:Question: What are the warning signs of cancer I shouldn ’ t ignore? Answer: I don ’ t have any warning signs of cancer. < / FREETEXT > < / PARAGRAPH > ▃ < PARAGRAPH > < FREETEXT > The patient ’ s family was concerned about the patient ’ s risk of developing cancer. The patient ’ s mother had a history of breast cancer. The patient ’ s father had a history of prostate cancer. The patient ’ s brother had a history of colon cancer. The patient ’ s sister had a history of breast cancer. The patient ’ s brother had a history of colon cancer. The patient ’ s brother had a history of colon cancer. The patient ’ s sister had a history of breast cancer. < / FREETEXT > < / PARAGRAPH > ▃ < PARAGRAPH > < FREETEXT > The patient ’ s mother had a history of breast cancer. The patient ’ s father had a history of prostate cancer. The patient ’ s brother had a history of colon cancer. The patient ’ s sister had a history of breast cancer. < / FREETEXT > < / PARAGRAPH > ▃ <
#
# question:What should I do if I can't sleep at night?
#  Answer:Question: What should I do if I can't sleep at night? Answer: I am not a good candidate for a sleep apnea patient. < / FREETEXT > < / TITLE > ▃
#
# question:Is it normal to hear a ringing in my ears?
#  Answer:Question: Is it normal to hear a ringing in my ears? Answer: The ringing is a normal part of the human voice. < / FREETEXT > < / TITLE > ▃
#
# question:How can I tell if a mole is dangerous?
#  Answer:Question: How can I tell if a mole is dangerous? Answer: The risk of malignant transformation of a mole is low, but it is important to recognize that a mole can be a sign of an underlying malignancy. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Are supplements like vitamin D necessary?
#  Answer:Question: Are supplements like vitamin D necessary? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I feel dizzy when I stand up quickly?
#  Answer:Question: Why do I feel dizzy when I stand up quickly? Answer: The cause is a balance disorder. < / FREETEXT > < / TITLE > ▃
#
# question:How long should a cold last?
#  Answer:Question: How long should a cold last? Answer: The duration of a cold is not a reliable indicator of the severity of a cold. < / FREETEXT > < / TITLE > ▃
#
# question:Is it okay to skip breakfast?
#  Answer:Question: Is it okay to skip breakfast? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:Can allergies develop later in life?
#  Answer:Question: Can allergies develop later in life? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:What is the difference between a cold and the flu?
#  Answer:Question: What is the difference between a cold and the flu? Answer: The flu is a viral infection that causes fever, chills, and cough. The cold is a viral infection that causes cough, sore throat, and runny nose. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Should I be worried about numbness in my fingers?
#  Answer:Question: Should I be worried about numbness in my fingers? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if I have high blood sugar?
#  Answer:Question: How do I know if I have high blood sugar? Answer: The blood sugar level is a result of the balance between the production of glucose by the body and the removal of glucose from the blood by the kidneys. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can diet really affect my mental health?
#  Answer:Question: Can diet really affect my mental health? Answer: There is no evidence that diet can affect mental health. < / FREETEXT > < / TITLE > ▃
#
# question:Why does my stomach hurt after eating?
#  Answer:Question: Why does my stomach hurt after eating? Answer: Hypersensitivity to wheat. < / FREETEXT > < / TITLE > ▃
#
# question:Can I exercise if I have joint pain?
#  Answer:Question: Can I exercise if I have joint pain? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:Is it safe to drink alcohol while taking antibiotics?
#  Answer:Question: Is it safe to drink alcohol while taking antibiotics? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:What is the healthiest way to quit smoking?
#  Answer:Question: What is the healthiest way to quit smoking? Answer: The combination of nicotine replacement therapy and behavioral therapy is the most effective treatment for smoking cessation. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Why do I bruise easily?
#  Answer:Question: Why do I bruise easily? Answer: The skin is a dynamic organ that is constantly exposed to mechanical forces. The skin is a viscoelastic tissue that is able to adapt to the mechanical forces. The skin is a viscoelastic tissue that is able to adapt to the mechanical forces. The skin is a viscoelastic tissue that is able to adapt to the mechanical forces. The skin is a viscoelastic tissue that is able to adapt to the mechanical forces. The skin is a viscoelastic tissue that is able to adapt to the mechanical forces. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can poor posture cause back pain?
#  Answer:Question: Can poor posture cause back pain? Answer: Poor posture is a risk factor for back pain. < / FREETEXT > < / TITLE > ▃
#
# question:Is my shortness of breath normal during exercise?
#  Answer:Question: Is my shortness of breath normal during exercise? Answer: Normal exercise-induced dyspnea is not necessarily dyspnea caused by heart failure. < / FREETEXT > < / TITLE > ▃
#
# question:What are common side effects of birth control?
#  Answer:Question: What are common side effects of birth control? Answer: The most common side effects of birth control are weight gain, menstrual irregularities, and breast tenderness. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Why do I feel anxious for no reason?
#  Answer:Question: Why do I feel anxious for no reason? Answer: The brain's emotional response to threat is a complex process that involves the amygdala, the prefrontal cortex, and the insula. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can I catch the same virus twice?
#  Answer:Question: Can I catch the same virus twice? Answer: The virus can be transmitted between patients. < / FREETEXT > < / TITLE > ▃
#
# question:How can I protect my vision as I age?
#  Answer:Question: How can I protect my vision as I age? Answer: The use of a multifocal contact lens can help. < / FREETEXT > < / TITLE > ▃
#
# question:Are probiotics actually beneficial?
#  Answer:Question: Are probiotics actually beneficial? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:What is the difference between IBS and IBD?
#  Answer:Question: What is the difference between IBS and IBD? Answer: IBS is a functional bowel disorder, and IBD is a chronic inflammatory bowel disease. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can too much caffeine affect my heart?
#  Answer:Question: Can too much caffeine affect my heart? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:Should I be worried about my cholesterol if I’m slim?
#  Answer:Question: Should I be worried about my cholesterol if I ’ m slim? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I get leg cramps at night?
#  Answer:Question: Why do I get leg cramps at night? Answer: The leg cramps are caused by a lack of blood flow to the legs. < / FREETEXT > < / TITLE > ▃
#
# question:What are the signs of an iron deficiency?
#  Answer:Question: What are the signs of an iron deficiency? Answer: The presence of microcytic anemia, hypoferremia, and low transferrin saturation are the main signs of iron deficiency. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can I drink coffee if I have high blood pressure?
#  Answer:Question: Can I drink coffee if I have high blood pressure? Answer: No. < / FREETEXT > < / TITLE > ▃
#
# question:Is it okay to take melatonin regularly?
#  Answer:Question: Is it okay to take melatonin regularly? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:How can I reduce my risk of dementia?
#  Answer:Question: How can I reduce my risk of dementia? Answer: Cognitive training may reduce the risk of dementia. < / FREETEXT > < / TITLE > ▃
#
# question:Why is my skin suddenly so dry?
#  Answer:Question: Why is my skin suddenly so dry? Answer: The skin is dry because of a lack of moisture-retaining substances. < / FREETEXT > < / TITLE > ▃
#
# question:Can I still get pregnant after 40?
#  Answer:Question: Can I still get pregnant after 40? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:What are normal blood sugar levels?
#  Answer:Question: What are normal blood sugar levels? Answer: The normal blood sugar level is between 4. 4 and 6. 1 mmol / L. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can dehydration cause headaches?
#  Answer:Question: Can dehydration cause headaches? Answer: There is no evidence to support the hypothesis that dehydration causes headaches. < / FREETEXT > < / TITLE > ▃
#
# question:How can I tell if I have a food intolerance?
#  Answer:Question: How can I tell if I have a food intolerance? Answer: Yes, if you have a food intolerance, you have a food allergy. < / FREETEXT > < / TITLE > ▃
#
# question:What vaccines do I need before traveling?
#  Answer:Question: What vaccines do I need before traveling? Answer: Live attenuated influenza vaccine. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if I need therapy?
#  Answer:Question: How do I know if I need therapy? Answer: If I have a low hemoglobin, I need to start therapy. < / FREETEXT > < / ABSTRACT > ▃
#
# question:How do I manage seasonal allergies?
#  Answer:Question: How do I manage seasonal allergies? Answer: The use of a combination of an intranasal corticosteroid and an oral antihistamine is the first-line treatment for seasonal allergic rhinitis. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Why do my hands tingle sometimes?
#  Answer:Question: Why do my hands tingle sometimes? Answer: The hands are the most common site of burning sensations in patients with primary erythromelalgia. < / FREETEXT > < / TITLE > ▃
#
# question:Can a lack of exercise cause health problems?
#  Answer:Question: Can a lack of exercise cause health problems? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:Should I be using sunscreen every day?
#  Answer:Question: Should I be using sunscreen every day? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:Is it normal to forget things more often with age?
#  Answer:Question: Is it normal to forget things more often with age? Answer: It is normal to forget things more often with age. < / FREETEXT > < / TITLE > ▃
#
# question:Can long-term screen time affect my eyesight?
#  Answer:Question: Can long-term screen time affect my eyesight? Answer: No. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I feel dizzy after standing up for a few seconds?
#  Answer:Question: Why do I feel dizzy after standing up for a few seconds? Answer: The patient's symptoms are caused by a compression of the left vertebral artery by the osteophytes of the cervical spine. < / FREETEXT > < / ABSTRACT > ▃
#
# question:How do I know if I am dehydrated?
#  Answer:Question: How do I know if I am dehydrated? Answer: The serum osmolality gap is a useful tool to assess dehydration in the ED. < / FREETEXT > < / ABSTRACT > ▃
#
# question:What should I do if my nosebleeds often?
#  Answer:Question: What should I do if my nosebleeds often? Answer: Stop bleeding and start treating the underlying cause. < / FREETEXT > < / TITLE > ▃
#
# question:Can stress cause stomach pain?
#  Answer:Question: Can stress cause stomach pain? Answer: Stress can cause stomach pain. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I sometimes feel my heart racing suddenly?
#  Answer:Question: Why do I sometimes feel my heart racing suddenly? Answer: The heart is a complex organ that is constantly working to maintain a balance between oxygen supply and demand. When the heart is unable to meet the demand, it can suddenly collapse. < / FREETEXT > < / ABSTRACT > ▃
#
# question:How do I know if my cough is due to allergies or a cold?
#  Answer:Question: How do I know if my cough is due to allergies or a cold? Answer: The patient's history is the best way to determine the cause of a cough. < / FREETEXT > < / ABSTRACT > ▃
#
# question:What should I do if I accidentally take the wrong medication dose?
#  Answer:Question: What should I do if I accidentally take the wrong medication dose? Answer: I should take the wrong medication dose. < / FREETEXT > < / TITLE > ▃
#
# question:Is it normal to feel short of breath when climbing stairs?
#  Answer:Question: Is it normal to feel short of breath when climbing stairs? Answer: The answer is yes. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I sometimes wake up with a headache?
#  Answer:Question: Why do I sometimes wake up with a headache? Answer: The headache is caused by a pressure on the brain stem. < / FREETEXT > < / TITLE > ▃
#
# question:How can I tell if I have low blood pressure?
#  Answer:Question: How can I tell if I have low blood pressure? Answer: I am not aware of any symptoms that might indicate low blood pressure. < / FREETEXT > < / TITLE > ▃
#
# question:Can lack of sleep cause weight gain?
#  Answer:Question: Can lack of sleep cause weight gain? Answer: Lack of sleep is associated with weight gain. < / FREETEXT > < / TITLE > ▃
#
# question:Why do my legs feel heavy at night?
#  Answer:Question: Why do my legs feel heavy at night? Answer: The leg muscles are not working properly at night. < / FREETEXT > < / TITLE > ▃
#
# question:What should I do if my vision suddenly becomes blurry?
#  Answer:Question: What should I do if my vision suddenly becomes blurry? Answer: I am not at risk for developing glaucoma. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if my back pain is serious?
#  Answer:Question: How do I know if my back pain is serious? Answer: I am not sure. < / FREETEXT > < / TITLE > ▃
#
# question:Why do my hands and feet get cold easily?
#  Answer:Question: Why do my hands and feet get cold easily? Answer: Cold hands and feet are a sign of Raynaud's phenomenon. < / FREETEXT > < / TITLE > ▃
#
# question:Can anxiety cause chest tightness?
#  Answer:Question: Can anxiety cause chest tightness? Answer: Anxiety can cause chest tightness. < / FREETEXT > < / TITLE > ▃
#
# question:How long should a bruise take to heal?
#  Answer:Question: How long should a bruise take to heal? Answer: The time to healing of bruises is highly variable. < / FREETEXT > < / TITLE > ▃
#
# question:What causes hiccups and how can I stop them?
#  Answer:Question: What causes hiccups and how can I stop them? Answer: Hiccups can be caused by gastroesophageal reflux disease. < / FREETEXT > < / TITLE > ▃
#
# question:Should I be concerned about occasional heart palpitations?
#  Answer:Question: Should I be concerned about occasional heart palpitations? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if I have vitamin deficiency?
#  Answer:Question: How do I know if I have vitamin deficiency? Answer: Vitamin D deficiency is a common problem in the elderly. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can digestive problems be related to stress?
#  Answer:Question: Can digestive problems be related to stress? Answer: There is a relationship between stress and digestive problems. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Why do I feel sleepy after eating?
#  Answer:Question: Why do I feel sleepy after eating? Answer: The sleep-wake cycle is regulated by the circadian clock, which is controlled by the suprachiasmatic nucleus (SCN). The SCN receives photic input from the retina and nonphotic input from the SCN core and shell. The SCN core receives photic input from the retina and nonphotic input from the SCN shell. The SCN core and shell are connected by reciprocal connections. The SCN core receives photic input from the retina and nonphotic input from the SCN shell. The SCN core and shell are connected by reciprocal connections. The SCN core and shell are connected by reciprocal connections. The SCN core and shell are connected by reciprocal connections. The SCN core and shell are connected by reciprocal connections. The SCN core and shell are connected by reciprocal connections. The SCN core and shell are connected by reciprocal connections. The SCN core and shell are connected by reciprocal connections. The SCN core and shell are connected by reciprocal connections. The SCN core and shell are connected by reciprocal connections. The SCN core and shell are connected by reciprocal connections. The
#
# question:Is it normal to sweat a lot at night?
#  Answer:Question: Is it normal to sweat a lot at night? Answer: It is normal to sweat a lot at night. < / FREETEXT > < / TITLE > ▃
#
# question:Can certain foods trigger migraines?
#  Answer:Question: Can certain foods trigger migraines? Answer: No. < / FREETEXT > < / TITLE > ▃
#
# question:What does it mean if I hear a popping sound in my joints?
#  Answer:Question: What does it mean if I hear a popping sound in my joints? Answer: The popping sound is a symptom of a joint disorder. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if I am having an allergic reaction to medication?
#  Answer:Question: How do I know if I am having an allergic reaction to medication? Answer: The patient has a history of a reaction to a medication, and the reaction is confirmed by a skin test. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Why do I get dizzy after intense exercise?
#  Answer:Question: Why do I get dizzy after intense exercise? Answer: The cause is a failure of the vestibular system to compensate for the loss of body position. < / FREETEXT > < / TITLE > ▃
#
# question:Can dehydration affect my heart rate?
#  Answer:Question: Can dehydration affect my heart rate? Answer: There is no evidence to support the hypothesis that dehydration affects heart rate. < / FREETEXT > < / TITLE > ▃
#
# question:What should I do if I feel sudden sharp pain in my abdomen?
#  Answer:Question: What should I do if I feel sudden sharp pain in my abdomen? Answer: I am not sure. < / FREETEXT > < / TITLE > ▃
#
# question:Can low iron cause dizziness?
#  Answer:Question: Can low iron cause dizziness? Answer: Low iron levels cause dizziness. < / FREETEXT > < / TITLE > ▃
#
# question:Is it normal to lose appetite when stressed?
#  Answer:Question: Is it normal to lose appetite when stressed? Answer: It is normal to lose appetite when stressed. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if I have sleep apnea?
#  Answer:Question: How do I know if I have sleep apnea? Answer: If you have a sleep apnea score, you can tell you if you have sleep apnea. < / FREETEXT > < / TITLE > ▃
#
# question:Can earwax buildup cause dizziness?
#  Answer:Question: Can earwax buildup cause dizziness? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:Why does my stomach bloat after eating certain foods?
#  Answer:Question: Why does my stomach bloat after eating certain foods? Answer: The bloating is caused by a food allergy. < / FREETEXT > < / TITLE > ▃
#
# question:What can I do to prevent leg swelling during long flights?
#  Answer:Question: What can I do to prevent leg swelling during long flights? Answer: The use of compression stockings is effective in preventing leg swelling during long flights. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can certain medications make me feel more tired?
#  Answer:Question: Can certain medications make me feel more tired? Answer: The use of certain medications, such as selective serotonin reuptake inhibitors, can cause fatigue. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Why do I sometimes feel tingling in my lips?
#  Answer:Question: Why do I sometimes feel tingling in my lips? Answer: The lip is a part of the brain. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if I am having an asthma attack?
#  Answer:Question: How do I know if I am having an asthma attack? Answer: I am having an asthma attack. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can a lack of physical activity cause constipation?
#  Answer:Question: Can a lack of physical activity cause constipation? Answer: There is a positive correlation between physical activity and stool frequency. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I sometimes feel my ear “pop” without being on a plane?
#  Answer:Question: Why do I sometimes feel my ear “pop ” without being on a plane? Answer: The ear is a complex organ that is sensitive to sound. The ear is composed of the tympanic membrane, ossicles, and the inner ear. The tympanic membrane is a thin membrane that covers the middle ear. The ossicles are bones that move the tympanic membrane. The inner ear is a complex organ that contains the cochlea, which is the sound-sensing part of the ear, and the vestibular system, which is the sense organ that detects head movements. The cochlea is a spiral of many turns. Each turn contains a different type of hair cell, which is the sensory cell of the ear. The inner ear is sensitive to sound waves. The sound waves are detected by the hair cells, which then send electrical signals to the brain. The vestibular system detects head movements. The signals are sent to the brain, which then controls the muscles that move the body. < / FREETEXT > < / PARAGRAPH > ▃ < PARAGRAPH > < FREETEXT > The ear is sensitive to sound waves. The sound waves are detected
#
# question:What should I do if I feel sudden weakness in my legs?
#  Answer:Question: What should I do if I feel sudden weakness in my legs? Answer: The patient's weakness is due to a spinal cord compression. < / FREETEXT > < / TITLE > ▃
#
# question:Can drinking too little water cause constipation?
#  Answer:Question: Can drinking too little water cause constipation? Answer: Drinking too little water causes constipation. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if I am overexercising?
#  Answer:Question: How do I know if I am overexercising? Answer: I am not overly active. < / FREETEXT > < / TITLE > ▃
#
# question:Is it normal to have mild chest discomfort after running?
#  Answer:Question: Is it normal to have mild chest discomfort after running? Answer: It is normal to have mild chest discomfort after running. < / FREETEXT > < / TITLE > ▃
#
# question:Why does my heart beat faster when I am anxious?
#  Answer:Question: Why does my heart beat faster when I am anxious? Answer: Anxiety is associated with increased sympathetic nervous system activity. < / FREETEXT > < / TITLE > ▃
#
# question:Can changes in weather trigger joint pain?
#  Answer:Question: Can changes in weather trigger joint pain? Answer: The weather is a trigger for joint pain. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I feel shaky when I haven’t eaten for a while?
#  Answer:Question: Why do I feel shaky when I haven ’ t eaten for a while? Answer: I am not a vegetarian, but I eat a lot of meat. < / FREETEXT > < / PARAGRAPH > ▃ < PARAGRAPH > < FREETEXT > The vegetarian diet is a healthy and balanced diet that is low in fat and high in fiber. It is also low in calories and has a high content of vitamins and minerals. The vegetarian diet is a good source of vitamins and minerals, and it is important to take these nutrients regularly. The vegetarian diet is also a good source of omega-3 fatty acids, which are important for the brain and heart. < / FREETEXT > < / PARAGRAPH > ▃ < PARAGRAPH > < FREETEXT > The vegetarian diet is also a good source of antioxidants, which are important for the body ’ s defense against oxidative stress. The vegetarian diet is also a good source of phytochemicals, which are natural compounds that are found in plants and are thought to have health benefits. Phytochemicals are also important for the body ’ s defense against oxidative stress. < /
#
# question:What should I do if I notice blood in my stool?
#  Answer:Question: What should I do if I notice blood in my stool? Answer: Do you have a blood in my stool? < / FREETEXT > < / TITLE > ▃
#
# question:Can stress cause irregular periods?
#  Answer:Question: Can stress cause irregular periods? Answer: Stress can cause irregular periods. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I get motion sickness in cars or boats?
#  Answer:Question: Why do I get motion sickness in cars or boats? Answer: The motion sickness is caused by the interaction of the visual and vestibular systems. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if I am lactose intolerant?
#  Answer:Question: How do I know if I am lactose intolerant? Answer: Lactose intolerance is a common condition that can be diagnosed by a lactose tolerance test. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can skipping meals affect my blood pressure?
#  Answer:Question: Can skipping meals affect my blood pressure? Answer: The answer is no. < / FREETEXT > < / TITLE > ▃
#
# question:What should I do if I accidentally swallow a small object?
#  Answer:Question: What should I do if I accidentally swallow a small object? Answer: I should remove the object. < / FREETEXT > < / TITLE > ▃
#
# question:Why does my throat feel tight sometimes?
#  Answer:Question: Why does my throat feel tight sometimes? Answer: The throat is a narrow tube that is lined with a layer of mucus that is easily broken down by coughing. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can lack of vitamin D cause fatigue?
#  Answer:Question: Can lack of vitamin D cause fatigue? Answer: There is no evidence to support a causal relationship between vitamin D deficiency and fatigue. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I get headaches when I don’t drink coffee?
#  Answer:Question: Why do I get headaches when I don ’ t drink coffee? Answer: Caffeine is a common headache trigger. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if I am allergic to pollen?
#  Answer:Question: How do I know if I am allergic to pollen? Answer: The skin prick test is the gold standard for diagnosing pollen allergy. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can using headphones for long periods affect my ears?
#  Answer:Question: Can using headphones for long periods affect my ears? Answer: Yes. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I feel lightheaded after a hot shower?
#  Answer:Question: Why do I feel lightheaded after a hot shower? Answer: The skin temperature of the hands is higher than the temperature of the feet. < / FREETEXT > < / TITLE > ▃
#
# question:What should I do if I faint suddenly?
#  Answer:Question: What should I do if I faint suddenly? Answer: I am not at risk for a serious cardiac event. < / FREETEXT > < / TITLE > ▃
#
# question:Can stress cause hair loss?
#  Answer:Question: Can stress cause hair loss? Answer: Stress can cause hair loss. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I sometimes feel like my heart skips a beat?
#  Answer:Question: Why do I sometimes feel like my heart skips a beat? Answer: The heart is a complex organ that is constantly pumping blood to the body. When the heart is not working properly, it can cause a heart attack. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can dehydration affect my mood?
#  Answer:Question: Can dehydration affect my mood? Answer: There is no evidence that dehydration affects mood. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if my fatigue is due to anemia?
#  Answer:Question: How do I know if my fatigue is due to anemia? Answer: Anemia is the most common cause of fatigue in the elderly. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Why do I feel bloated during my menstrual cycle?
#  Answer:Question: Why do I feel bloated during my menstrual cycle? Answer: The menstrual cycle is associated with increased sympathetic nervous system activity. < / FREETEXT > < / TITLE > ▃
#
# question:Can too much exercise affect my immune system?
#  Answer:Question: Can too much exercise affect my immune system? Answer: There is no evidence that too much exercise can affect the immune system. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Why does my skin itch without a rash?
#  Answer:Question: Why does my skin itch without a rash? Answer: The itch is caused by a primary skin disease. < / FREETEXT > < / TITLE > ▃
#
# question:Can certain foods make heartburn worse?
#  Answer:Question: Can certain foods make heartburn worse? Answer: Some foods can make heartburn worse. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I sometimes feel pressure in my ears?
#  Answer:Question: Why do I sometimes feel pressure in my ears? Answer: The pressure in my ears is caused by the pressure of the air in my nose. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if my frequent urination is normal?
#  Answer:Question: How do I know if my frequent urination is normal? Answer: The patient's voiding diary is a useful tool to help determine if a patient's frequent urination is normal. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can changes in sleep schedule affect my digestion?
#  Answer:Question: Can changes in sleep schedule affect my digestion? Answer: Sleep restriction does not affect gastric emptying. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I feel sudden chills without fever?
#  Answer:Question: Why do I feel sudden chills without fever? Answer: The sudden chills are caused by the activation of the sympathetic nervous system. < / FREETEXT > < / ABSTRACT > ▃
#
# question:How do I know if my wound is infected?
#  Answer:Question: How do I know if my wound is infected? Answer: The wound swab is the gold standard for diagnosing wound infection. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can anxiety cause tingling in the body?
#  Answer:Question: Can anxiety cause tingling in the body? Answer: Anxiety can cause tingling in the body. < / FREETEXT > < / TITLE > ▃
#
# question:Why do I sometimes lose balance when turning quickly?
#  Answer:Question: Why do I sometimes lose balance when turning quickly? Answer: The balance between the muscles that move the body forward and those that move the body backward is essential for maintaining balance. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Can dehydration cause muscle cramps?
#  Answer:Question: Can dehydration cause muscle cramps? Answer: There is no evidence to support the hypothesis that dehydration causes muscle cramps. < / FREETEXT > < / ABSTRACT > ▃
#
# question:How do I know if my blood sugar is too low without a test?
#  Answer:Question: How do I know if my blood sugar is too low without a test? Answer: If you have a glucometer, you can measure your blood sugar and use it to make a diagnosis. < / FREETEXT > < / ABSTRACT > ▃
#
# question:Why do I wake up feeling like my heart is racing?
#  Answer:Question: Why do I wake up feeling like my heart is racing? Answer: The heart is racing, and the brain is racing. < / FREETEXT > < / TITLE > ▃
#
# question:Can eating too fast cause stomach pain?
#  Answer:Question: Can eating too fast cause stomach pain? Answer: Eating too fast can cause stomach pain. < / FREETEXT > < / TITLE > ▃
#
# question:How do I know if my headache is from eye strain?
#  Answer:Question: How do I know if my headache is from eye strain? Answer: I am not sure. < / FREETEXT > < / TITLE > ▃
#
# question:Can cold weather trigger breathing difficulties?
#  Answer:Question: Can cold weather trigger breathing difficulties? Answer: The answer is no. < / FREETEXT > < / TITLE > ▃

# %%
import json
tout2=[]
for q,r in zip(query,A):
    data_json_biogpt_RAG = {"question": q, "answer": r}
    tout2.append(data_json_biogpt_RAG)
with open("biogpt_answer.json", "w", encoding="utf-8") as f:
           json.dump(tout2, f, ensure_ascii=False, indent=4)
